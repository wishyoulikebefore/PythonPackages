# %%
from IPython.display import Latex
# %%latex

# %% [markdown]
# # 使用说明
# 创建显示模式的表达式，使用 $$符
#
# 命令内参数用{}包含

# %%
# %%latex
# $$P(A \mid B) = \frac{ P(B \mid A) P(A) }{ P(B) }$$
# Out:
# $$P(A \mid B) = \frac{ P(B \mid A) P(A) }{ P(B) }$$

# %%
# %%latex
# $$x^2$$
# $$e^2x$$
# $$e^{2x}$$
# $$x_i$$
# $$\underset{k}{argmax}$$
# $$ \sqrt{2\pi} $$
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
# $$\sin, \cosh, \arctan$$
# $$\leq, \geq, \approx, \neq$$
# $$\times, \pm, \cup, \oplus$$
# $$\cdots, \ldots, \ddots$$
# $$\bar x$$
# $$\overline{abs}$$
# $$\vec{x}, \overrightarrow{AB}$$
# $\underbrace{a+b+\cdots+j}_{10}$
# Out:
# $$x^2$$
# $$e^2x$$
# $$e^{2x}$$
# $$x_i$$
# $$\underset{k}{argmax}$$
# $$ \sqrt{2\pi} $$
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
# $$\sin, \cosh, \arctan$$
# $$\leq, \geq, \approx, \neq$$
# $$\times, \pm, \cup, \oplus$$
# $$\cdots, \ldots, \ddots$$
# $$\bar x$$
# $$\overline{abs}$$
# $$\vec{x}, \overrightarrow{AB}$$
# $\underbrace{a+b+\cdots+j}_{10}$

# %%
# %%latex
# $$z=(\frac{dx}{dy})^{1/3}$$
# $$z=\left(\frac{dx}{dy}\right)^{1/3}$$
# Out:
# $$z=(\frac{dx}{dy})^{1/3}$$
# $$z=\left(\frac{dx}{dy}\right)^{1/3}$$

# %%
# %%latex
# $$\left[\begin{matrix}a & b \cr c & d\end{matrix}\right]$$
# Out:
# $$\left[\begin{matrix}a & b \cr c & d\end{matrix}\right]$$

# %%
# %%latex
# $$\boldsymbol{A\cdot x}=\lambda\cdot v$$
# Out:
# $$\boldsymbol{A\cdot x}=\lambda\cdot v$$

# %%
# %%latex
# $$\int f(x)\; dx$$
# Out:
# $$\int f(x)\; dx$$

# %%
# %%latex
# $$
# \begin{align}
# a_1&=b_1+c_1 \\
# a_2&=b_2+c_2+d_2 \\
# a_3&=b_3+c_3
# \end{align}
# $$
# Out:
# $$
# \begin{align}
# a_1&=b_1+c_1 \\
# a_2&=b_2+c_2+d_2 \\
# a_3&=b_3+c_3
# \end{align}
# $$

# %%
# %%latex
# $$
# sign(x)=\begin{cases}
# 1,&x>0 \\ 0,&x=0 \cr -1,&x<0
# \end{cases}
# $$
# Out:
# $$
# sign(x)=\begin{cases}
# 1,&x>0 \\ 0,&x=0 \cr -1,&x<0
# \end{cases}
# $$

# %%
# %%latex
# $$\int_{0}^{\pi}{\tan x}$$
# $$\sum_{i=0}^{n}{i}$$
# $$\prod_{i=1}^{9}{i}$$
# Out:
# $$\int_{0}^{\pi}{\tan x}$$
# $$\sum_{i=0}^{n}{i}$$
# $$\prod_{i=1}^{9}{i}$$

# %% [markdown]
# ## 数学符号

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/数学符号.jpg',width=600,height=400)

# %% [markdown]
# ## 二元关系符

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/二元关系符.jpg',width=600,height=400)

# %% [markdown]
# ## 二元运算符

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/二元运算符.jpg',width=600,height=400)

# %% [markdown]
# ## 箭头&定界符

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/箭头定界符.jpg',width=600,height=400)

# %% [markdown]
# ## 其它

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/其它.jpg',width=600,height=400)
