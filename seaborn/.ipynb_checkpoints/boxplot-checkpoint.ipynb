# %% [markdown]
# boxplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, fliersize=5, linewidth=None, whis=1.5, notch=False, ax=None, **kwargs)

# %%
import seaborn as sns
import matplotlib

# %matplotlib inline

sns.set(style="ticks")

tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips, palette="PRGn")
sns.despine(offset=10, trim=True)

# %%
#或者利用factorplot
sns.factorplot(x="day", y="total_bill", hue="sex", data=tips,kind="box",palette="PRGn",legend_out=False)

# %% [markdown]
# ### horizontal boxplot（自动判定）

# %%
import numpy as np

sns.set(style="ticks")
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

planets = sns.load_dataset("planets")
sns.boxplot(x="distance", y="method", data=planets,
            whis=np.inf, palette="vlag")
sns.swarmplot(x="distance", y="method", data=planets,
              size=2, color=".3", linewidth=0)
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
# Out:
# c:\users\zty\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\__init__.py:1233: RuntimeWarning: invalid value encountered in double_scalars
#   loval = q1 - whis * stats['iqr']
# c:\users\zty\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\__init__.py:1234: RuntimeWarning: invalid value encountered in double_scalars
#   hival = q3 + whis * stats['iqr']
# c:\users\zty\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\__init__.py:1246: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# c:\users\zty\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\__init__.py:1253: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# [Text(0, 0.5, '')]
