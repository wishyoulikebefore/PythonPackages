# %%
from pyecharts import Gauge
from pyecharts_snapshot.main import make_a_snapshot

gauge = Gauge("仪表盘示例")
gauge.add("业务指标", "完成率", 166.66, angle_range=[180, 0],
          scale_range=[0, 200], is_legend_show=False)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="35fa35e9d43943d0a576869a12673bfc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_35fa35e9d43943d0a576869a12673bfc = echarts.init(document.getElementById('35fa35e9d43943d0a576869a12673bfc'), 'light', {renderer: 'canvas'});
#
# var option_35fa35e9d43943d0a576869a12673bfc = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "show": false,
#             "top": "top",
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ]
#         }
#     ],
#     "series_id": 7527818,
#     "series": [
#         {
#             "detail": {
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "endAngle": 0,
#             "type": "gauge",
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "startAngle": 180,
#             "max": 200,
#             "data": [
#                 {
#                     "value": 166.66,
#                     "name": "\u5b8c\u6210\u7387"
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "text": "\u4eea\u8868\u76d8\u793a\u4f8b",
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "left": "95%"
#     },
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333",
#         "formatter": "{a} <br/>{b} : {c}%"
#     }
# };
# myChart_35fa35e9d43943d0a576869a12673bfc.setOption(option_35fa35e9d43943d0a576869a12673bfc);
#
#     });
# </script>
