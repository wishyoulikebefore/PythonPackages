# %% [markdown]
# jointplot(x, y, data=None, kind='scatter', stat_func=<function pearsonr>,color=None,
#        height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None,
#        marginal_kws=None, annot_kws=None, **kwargs)
# #同时绘制出单变量图和双变量图

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style="darkgrid", color_codes=True)

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.jointplot("total_bill", "tip", data=tips, kind="reg",xlim=(0, 60), ylim=(0, 12), color="r", height=7)
