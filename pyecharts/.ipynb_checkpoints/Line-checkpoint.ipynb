# %% [markdown]
# Line.add(name, x_axis, y_axis,is_symbol_show=True,is_smooth=False,is_stack=False,is_step=False,is_fill=False, **kwargs)

# %%
from pyecharts import Line
from pyecharts_snapshot.main import make_a_snapshot

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 10, 100]
v2 = [55, 60, 16, 20, 15, 80]
line = Line("折线图示例")
line.add("商家A", attr, v1, mark_point=["average"])
line.add("商家B", attr, v2, is_smooth=True, mark_line=["max", "average"])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f4124d18923b4a30b66ca3415c5b7cd5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f4124d18923b4a30b66ca3415c5b7cd5 = echarts.init(document.getElementById('f4124d18923b4a30b66ca3415c5b7cd5'), 'light', {renderer: 'canvas'});
#
# var option_f4124d18923b4a30b66ca3415c5b7cd5 = {
#     "series": [
#         {
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbolSize": 50,
#                         "type": "average",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "smooth": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "seriesId": 314951,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     5
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     20
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     36
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     10
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     10
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     100
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": []
#             },
#             "step": false,
#             "type": "line",
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1
#                 }
#             },
#             "name": "\u5546\u5bb6A",
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "tooltip": {
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "top": "top",
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "show": true,
#             "selectedMode": "multiple",
#             "orient": "horizontal"
#         }
#     ],
#     "series_id": 314951,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             }
#         },
#         "left": "95%"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "inverse": false,
#             "show": true,
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameLocation": "middle",
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameLocation": "middle",
#             "inverse": false,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25
#         }
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "text": "\u6298\u7ebf\u56fe\u793a\u4f8b",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ]
# };
# myChart_f4124d18923b4a30b66ca3415c5b7cd5.setOption(option_f4124d18923b4a30b66ca3415c5b7cd5);
#
#     });
# </script>
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f4124d18923b4a30b66ca3415c5b7cd5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f4124d18923b4a30b66ca3415c5b7cd5 = echarts.init(document.getElementById('f4124d18923b4a30b66ca3415c5b7cd5'), 'light', {renderer: 'canvas'});
#
# var option_f4124d18923b4a30b66ca3415c5b7cd5 = {
#     "series": [
#         {
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbolSize": 50,
#                         "type": "average",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         },
#                         "symbol": "pin",
#                         "name": "mean-Value"
#                     }
#                 ]
#             },
#             "smooth": false,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "seriesId": 314951,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     5
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     20
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     36
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     10
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     10
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     100
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": []
#             },
#             "step": false,
#             "type": "line",
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1
#                 }
#             },
#             "name": "\u5546\u5bb6A",
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "markPoint": {
#                 "data": []
#             },
#             "smooth": true,
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "seriesId": 314951,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     55
#                 ],
#                 [
#                     "\u7f8a\u6bdb\u886b",
#                     60
#                 ],
#                 [
#                     "\u96ea\u7eba\u886b",
#                     16
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     20
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     15
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     80
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum"
#                     },
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "step": false,
#             "type": "line",
#             "lineStyle": {
#                 "normal": {
#                     "type": "solid",
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1
#                 }
#             },
#             "name": "\u5546\u5bb6B",
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "tooltip": {
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "top": "top",
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "show": true,
#             "selectedMode": "multiple",
#             "orient": "horizontal"
#         }
#     ],
#     "series_id": 314951,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             }
#         },
#         "left": "95%"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "inverse": false,
#             "show": true,
#             "boundaryGap": true,
#             "nameGap": 25,
#             "axisLabel": {
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameLocation": "middle",
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "type": "category",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
