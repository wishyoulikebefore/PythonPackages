# %% [markdown]
# ## 理解卷积（convolution）

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=400,height=600)

# %% [markdown]
# 一个函数（如：单位响应）在另一个函数（如：输入信号）上的加权叠加

# %% [markdown]
# ### 离散卷积：丢骰子
# 求两个骰子加起来等于4的概率

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %% [markdown]
# 两枚骰子点数加起来为4的情况有
# > f(1)g(3)
#
# > f(2)g(2)
#
# > f(3)g(1)
#
# 合计： f(1)g(3) + f(2)g(2) + f(3)g(1)
#
# 符合卷积的定义，写成标准的形式就是：

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=300,height=400)

# %% [markdown]
# ### 连续卷积：做馒头

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %% [markdown]
# ### 图像处理中的应用

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %% [markdown]
# 图像中的噪点需要平滑，即与噪点周围值平均一下

# %%
#处理后
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/2.jpg",width=300,height=400)

# %%
#把图像转化为矩阵，作为f函数
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %% [markdown]
# 正态分布矩阵充当g函数

# %%
#实现过程
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/2.jpg",width=600,height=800)

# %%
#动图展示过程
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.gif",width=600,height=800)

# %%
#写成卷积公式
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=300,height=400)

# %%
#g函数旋转了180°，在f函数上滑动
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.gif",width=400,height=600)

# %% [markdown]
# ## 为什么叫卷积

# %% [markdown]
# ### 解释1
# 看起来像把一张二维的地毯从角沿45度斜线卷起来

# %%
#以下是一张正方形地毯，上面保存着f和g在区间[a,b]的张量积，即U(x,y)=f(x)g(y)
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %%
#把一角卷起来
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/2.jpg",width=600,height=800)

# %%
#全部卷起来后，成为一维函数，每点的值等于卷起来后重合的点函数值之和
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/3.jpg",width=600,height=800)

# %%
#展开，之前划线处恰好是x+y为定值的一条直线，所以卷起来后那点的函数值正好为这条直线上函数值的积分
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/4.png",width=600,height=800)

# %% [markdown]
# ### 解释2
# 把二元函数 U(x,y) = f(x)g(y) 卷成一元函数V(t)，俗称降维打击

# %%
from IPython.display import Image
Image(filename="C:/Users/zuo_tianyu0101/Desktop/1.jpg",width=600,height=800)

# %% [markdown]
# ## 反卷积（deconvolution）
# 是指通过计算输出和已知输入，求未知输入的过程
# https://www.zhihu.com/question/48279880

# %% [markdown]
# 傅里叶变换
# https://blog.csdn.net/wenzhilu/article/details/79079183
