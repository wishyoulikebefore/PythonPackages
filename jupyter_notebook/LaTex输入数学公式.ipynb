# %%
from IPython.display import Latex
# %%latex

# %% [markdown]
# # 段落

# %% [raw]
# 内联换行： $
# $V​max​​$ is R, G, or B.
#
# 块换行： $$
# $$H←  ​​​​​0 ​+​ \frac{​​30(G−B)​​}{Vmax−Vmin}  ​​, if V​max​​ = R$$
#
# 块换行： \begin{equation}和\end{equation}
# \begin{equation}
# H← ​​​60 ​+​ \frac{​​30(B−R)​​}{Vmax−Vmin}  ​​, if V​max​​ = G
# \end{equation}
#
# 块，换行： \begin{align}和\end{align}
# \begin{align}
# H←120 ​+​ \frac{​​30(R−G)​​}{Vmax−Vmin}  ​​, if V​max​​ = B
# \end{align}

# %% [markdown]
# # 希腊字母

# %%
from IPython.display import Image
Image(filename="C:/Users/86188/Desktop/希腊字母.jpg",width=600,height=400)

# %% [markdown]
# # 常见数学公式

# %% [markdown]
# ## 分数

# %%
# %%latex
# $$P(A \mid B) = \frac{ P(B \mid A) P(A) }{ P(B) }$$
# Out:
# $$P(A \mid B) = \frac{ P(B \mid A) P(A) }{ P(B) }$$

# %%
# %%latex
# $$x^2$$
# $$e^2x$$
# $$e^{2x}$$
# $$x_i$$
# $$\underset{k}{argmax}$$
# $$ \sqrt{2\pi} $$
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
# $$\sin, \cosh, \arctan$$
# $$\leq, \geq, \approx, \neq$$
# $$\times, \pm, \cup, \oplus$$
# $$\cdots, \ldots, \ddots$$
# $$\bar x$$
# $$\overline{abs}$$
# $$\vec{x}, \overrightarrow{AB}$$
# $\underbrace{a+b+\cdots+j}_{10}$
# Out:
# $$x^2$$
# $$e^2x$$
# $$e^{2x}$$
# $$x_i$$
# $$\underset{k}{argmax}$$
# $$ \sqrt{2\pi} $$
# $$\alpha, \beta, \gamma$$
# $$\Phi, \Lambda, \Gamma$$
# $$\sin, \cosh, \arctan$$
# $$\leq, \geq, \approx, \neq$$
# $$\times, \pm, \cup, \oplus$$
# $$\cdots, \ldots, \ddots$$
# $$\bar x$$
# $$\overline{abs}$$
# $$\vec{x}, \overrightarrow{AB}$$
# $\underbrace{a+b+\cdots+j}_{10}$

# %% [markdown]
# ## 一般括号

# %%
# %%latex
# $$z=(\frac{dx}{dy})^{1/3}$$
# $$z=\left(\frac{dx}{dy}\right)^{1/3}$$
# Out:
# $$z=(\frac{dx}{dy})^{1/3}$$
# $$z=\left(\frac{dx}{dy}\right)^{1/3}$$

# %% [markdown]
# ## 矩阵括号

# %%
# %%latex
# $$\left[\begin{matrix}a & b \cr c & d\end{matrix}\right]$$
# Out:
# $$\left[\begin{matrix}a & b \cr c & d\end{matrix}\right]$$

# %% [markdown]
# ## 矩阵乘法

# %%
# %%latex
# $$\boldsymbol{A\cdot x}=\lambda\cdot v$$
# Out:
# $$\boldsymbol{A\cdot x}=\lambda\cdot v$$

# %% [markdown]
# ## 空格
#  \, 或 \: 或 \;添加空格，其空格宽度分别为从小到大

# %%
# %%latex
# $$\int f(x)\; dx$$
# Out:
# $$\int f(x)\; dx$$

# %% [markdown]
# ## 左对齐

# %%
# %%latex
# $$
# \begin{align}
# a_1&=b_1+c_1 \\
# a_2&=b_2+c_2+d_2 \\
# a_3&=b_3+c_3
# \end{align}
# $$
# Out:
# $$
# \begin{align}
# a_1&=b_1+c_1 \\
# a_2&=b_2+c_2+d_2 \\
# a_3&=b_3+c_3
# \end{align}
# $$

# %% [markdown]
# ## 分段函数

# %%
# %%latex
# $$
# sign(x)=\begin{cases}
# 1,&x>0 \\ 0,&x=0 \cr -1,&x<0
# \end{cases}
# $$
# Out:
# $$
# sign(x)=\begin{cases}
# 1,&x>0 \\ 0,&x=0 \cr -1,&x<0
# \end{cases}
# $$

# %% [markdown]
# ## 运算符

# %%
# %%latex
# $$\int_{0}^{\pi}{\tan x}$$
# $$\sum_{i=0}^{n}{i}$$
# $$\prod_{i=1}^{9}{i}$$
# Out:
# $$\int_{0}^{\pi}{\tan x}$$
# $$\sum_{i=0}^{n}{i}$$
# $$\prod_{i=1}^{9}{i}$$
