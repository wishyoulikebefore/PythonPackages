# %% [markdown]
# ### 主要用于地理区域数据的可视化
# Map.add(name, attr, value, is_roam=True, maptype=”china”, **kwargs)
#
# >name –> str : 图例名称
#
# >attr –> list : 属性名称
#
# >value –> list : 属性所对应的值.
#
# >maptype –> str : 地图属性, 支持 china, world, 安徽、澳门、北京、重庆、福建、福建、甘肃、广东，广西、广州、海南、河北、黑龙江、河南、湖北、湖南、江苏、江西、吉林、辽宁、内蒙古、宁夏、青海、山东、上海、陕西、四川、台湾、天津、香港、新疆、西藏、云南、浙江. 地图提供了(自定义模式)
#
# >is_map_symbol_show -> bool是否显示地图标记红点，默认为 True。

# %%
from pyecharts_snapshot.main import make_a_snapshot
from pyecharts import Map

value = [155, 10, 66, 78, 33, 80, 190, 53, 49.6]
attr = ["福建", "山东", "北京", "上海", "甘肃", "新疆", "河南", "广西", "西藏"]
map = Map("Map 结合 VisualMap 示例", width=1200, height=600)
map.add(
    "",
    attr,
    value,
    maptype="china",
    is_visualmap=True,
    visual_text_color="#000",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="c3d0f5ec1afb49368eef8485e37bce2b" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_c3d0f5ec1afb49368eef8485e37bce2b = echarts.init(document.getElementById('c3d0f5ec1afb49368eef8485e37bce2b'), 'light', {renderer: 'canvas'});
#
# var option_c3d0f5ec1afb49368eef8485e37bce2b = {
#     "visualMap": {
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "text": [
#             "high",
#             "low"
#         ],
#         "splitNumber": 5,
#         "textStyle": {
#             "color": "#000"
#         },
#         "max": 100,
# ...

# %%
from pyecharts_snapshot.main import make_a_snapshot
from pyecharts import Map

value = [95.1, 23.2, 43.3, 66.4, 88.5]
attr= ["China", "Canada", "Brazil", "Russia", "United States"]
map = Map("世界地图示例", width=1200, height=600)
map.add(
    "",
    attr,
    value,
    maptype="world",
    is_visualmap=True,
    visual_text_color="#000",
    is_map_symbol_show=False,
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'world': '/nbextensions/echarts-countries-js/world'
#         }
#     });
# </script>
#     <div id="147513b8fd414016a69637d0fa1f33aa" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#
# var myChart_147513b8fd414016a69637d0fa1f33aa = echarts.init(document.getElementById('147513b8fd414016a69637d0fa1f33aa'), 'light', {renderer: 'canvas'});
#
# var option_147513b8fd414016a69637d0fa1f33aa = {
#     "visualMap": {
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "text": [
#             "high",
#             "low"
#         ],
#         "splitNumber": 5,
#         "textStyle": {
#             "color": "#000"
#         },
#         "max": 100,
# ...
