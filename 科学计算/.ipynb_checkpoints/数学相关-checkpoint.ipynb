# %%
import numpy as np
import scipy as sp
from scipy.optimize import leastsq
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 创建多项式
# np.poly1d(c_or_r, r=False)
#
# > poly1d([1, 2, 3]) 相当于math:x^2 + 2x + 3
#
# > poly1d([1, 2, 3], True) 相当于math:(x-1)(x-2)(x-3) = x^3 - 6x^2 + 11x -6

# %% [markdown]
# # 最小二乘法
# leastsq(func, x0, args=())
# > x0:初始参数
#
# > args: 额外参数
#
# 返回值为拟合曲线的系数array

# %%
def real_func(x):
    return np.sin(2*np.pi*x)

def fit_func(p, x):
    f = np.poly1d(p)
    return f(x)

# 残差
def residuals_func(p, x, y):
    ret = fit_func(p, x) - y
    return ret

x = np.linspace(0, 1, 10)
x_points = np.linspace(0, 1, 1000)
# 加上正态分布噪音的目标函数的值
y_ = real_func(x)
y = [np.random.normal(0, 0.1)+y1 for y1 in y_]

def fitting(M=0):
    """
    M为多项式的次数
    """    
    # 随机初始化多项式参数
    p_init = np.random.rand(M+1)
    # 最小二乘法
    p_lsq = leastsq(residuals_func, p_init, args=(x, y))
    print('Fitting Parameters:', p_lsq[0])
    
    # 可视化
    plt.plot(x_points, real_func(x_points), label='real')
    plt.plot(x_points, fit_func(p_lsq[0], x_points), label='fitted curve')
    plt.plot(x, y, 'bo', label='noise')
    plt.legend()
    return p_lsq

# %%
p_lsq_1 = fitting(M=1)
# Out:
# Fitting Parameters: [-1.30096431  0.6708294 ]

# %%
p_lsq_3 = fitting(M=3)
# Out:
# Fitting Parameters: [ 18.98184556 -28.34118341   9.37069867   0.03416089]

# %% [markdown]
# # 协方差
# cov(m, y=None, rowvar=True)
# > 默认rowvar=True，即index指代变量，columns指代观察值
#
# > 计算结果：对角线为方差
