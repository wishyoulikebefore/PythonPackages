# %% [raw]
# 完成任务：
# 相互校验tushare和baostock的数据准确性

# %% [markdown]
# # baostock

# %% [markdown]
# 获取K线数据
#
# bs.query_history_k_data_plus(
#     code,
#     fields,
#     start_date=None,
#     end_date=None,
#     frequency='d',
#     adjustflag='3',
# )
#
# 参数说明：
#
# frequency：数据类型，默认为d，日k线；d=日k线、w=周、m=月、5=5分钟、15=15分钟、30=30分钟、60=60分钟k线数据，不区分大小写
# > 指数没有分钟线数据(需要tushare补充)
#
# > 周线每周最后一个交易日才可以获取，月线每月最后一个交易日才可以获取

# %%
import baostock as bs
import pandas as pd
import numpy as np

# %%
# 封装函数
def baostock_get_history_k_data(code,start_date,end_date,frequency,adjustflag="3"):
    lg = bs.login()
    rs = bs.query_history_k_data_plus(code,"date,open,high,low,close,preclose,volume,amount,turn,tradestatus,pctChg,isST",
                                        start_date, end_date, frequency, adjustflag)
    data_list = []
    while (rs.error_code == '0') & rs.next():
        data_list.append(rs.get_row_data())
    result = pd.DataFrame(data_list, columns=rs.fields, dtype=np.float)
    result["turn"] = result["turn"]*100
    result["amount"] = result["amount"]/100000000
    result.set_index("date",inplace=True)
    del rs.fields[0]
    decimals = pd.Series([2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 0], index=rs.fields)
    result = result.round(decimals)
    return result

# %%
lg = bs.login()
# Out:
# login success!

# %%
rs = bs.query_history_k_data_plus("sh.600000",
    "date,open,high,low,close,preclose,volume,amount,turn,tradestatus,pctChg,isST",
    start_date='2017-07-01', end_date='2017-12-31',
    frequency="d", adjustflag="3")

data_list = []
while (rs.error_code == '0') & rs.next():
    data_list.append(rs.get_row_data())
result = pd.DataFrame(data_list, columns=rs.fields, dtype=np.float)

result["turn"] = result["turn"]*100
result.set_index("date",inplace=True)

del rs.fields[0]
decimals = pd.Series([2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 0], index=rs.fields)
result = result.round(decimals)

# %%
result
# Out:
#              open   high    low  close  preclose      volume       amount  \
# date
# 2017-07-03  12.64  12.65  12.47  12.56     12.65  38778949.0  486264672.0
# 2017-07-04  12.55  12.58  12.41  12.55     12.56  36659128.0  458434432.0
# 2017-07-05  12.50  12.65  12.47  12.62     12.55  26470507.0  332542464.0
# 2017-07-06  12.62  12.72  12.51  12.66     12.62  37414241.0  471582096.0
# 2017-07-07  12.62  12.69  12.55  12.60     12.66  24667294.0  311101536.0
# ...           ...    ...    ...    ...       ...         ...          ...
# 2017-12-25  12.61  12.68  12.56  12.59     12.62  19306662.0  243553698.0
# 2017-12-26  12.57  12.66  12.56  12.64     12.59  15225722.0  192219131.0
# 2017-12-27  12.65  12.66  12.53  12.62     12.64  32731881.0  412197987.0
# 2017-12-28  12.60  12.66  12.53  12.54     12.62  23870824.0  300834017.0
# 2017-12-29  12.52  12.62  12.51  12.59     12.54  16351826.0  205752875.0
#
#              turn  tradestatus  pctChg  isST
# date
# 2017-07-03  13.80          1.0   -0.71   0.0
# 2017-07-04  13.04          1.0   -0.08   0.0
# 2017-07-05   9.42          1.0    0.56   0.0
# 2017-07-06  13.31          1.0    0.32   0.0
# 2017-07-07   8.78          1.0   -0.47   0.0
# ...           ...          ...     ...   ...
# 2017-12-25   6.87          1.0   -0.24   0.0
# 2017-12-26   5.42          1.0    0.40   0.0
# 2017-12-27  11.65          1.0   -0.16   0.0
# 2017-12-28   8.49          1.0   -0.63   0.0
# 2017-12-29   5.82          1.0    0.40   0.0
#
# [125 rows x 11 columns]

# %%
rs2 = bs.query_history_k_data_plus("sh.000001",
    "date,code,open,high,low,close,preclose,volume,amount,pctChg",
    start_date='2020-03-10', end_date='2020-04-03', frequency="d")

# 综合指数，例如：sh.000001 上证指数，sz.399106 深证综指 等；
# 规模指数，例如：sh.000016 上证50，sh.000300 沪深300，sh.000905 中证500，sz.399001 深证成指等

# %%
sh_data = []
while (rs2.error_code == '0') & rs2.next():
    # 获取一条记录，将记录合并在一起
    sh_data.append(rs2.get_row_data())
result2 = pd.DataFrame(sh_data, columns=rs2.fields)

# %%
result2
# Out:
#           date       code       open       high        low      close  \
# 0   2020-03-10  sh.000001  2918.9347  3000.2963  2904.7989  2996.7618
# 1   2020-03-11  sh.000001  3001.7616  3010.0286  2968.5174  2968.5174
# 2   2020-03-12  sh.000001  2936.0163  2944.4651  2906.2838  2923.4856
# 3   2020-03-13  sh.000001  2804.2322  2910.8812  2799.9841  2887.4265
# 4   2020-03-16  sh.000001  2897.3009  2898.0349  2784.6616  2789.2537
# 5   2020-03-17  sh.000001  2796.2840  2826.9068  2715.2213  2779.6407
# 6   2020-03-18  sh.000001  2792.3221  2815.8737  2729.2423  2729.6185
# 7   2020-03-19  sh.000001  2719.4063  2736.8200  2646.8048  2702.1296
# 8   2020-03-20  sh.000001  2727.0186  2751.8964  2702.4933  2745.6182
# 9   2020-03-23  sh.000001  2677.5910  2703.3295  2656.5008  2660.1674
# 10  2020-03-24  sh.000001  2703.0193  2723.4066  2667.1333  2722.4381
# 11  2020-03-25  sh.000001  2775.3032  2788.6354  2757.8016  2781.5913
# 12  2020-03-26  sh.000001  2761.8961  2788.5038  2753.4282  2764.9109
# 13  2020-03-27  sh.000001  2792.9843  2805.5479  2771.7563  2772.2033
# 14  2020-03-30  sh.000001  2739.7191  2759.0989  2723.0543  2747.2138
# 15  2020-03-31  sh.000001  2767.3072  2771.1683  2743.1154  2750.2962
# 16  2020-04-01  sh.000001  2743.5409  2773.3641  2731.0794  2734.5215
# 17  2020-04-02  sh.000001  2720.2284  2780.6379  2719.9043  2780.6379
# 18  2020-04-03  sh.000001  2773.5764  2780.5868  2754.0731  2763.9874
#
#      preclose       volume             amount     pctChg
# 0   2943.2907  39329664800  425017184790.9000   1.816711
# 1   2996.7618  35247097000  378766618968.3000  -0.942497
# 2   2968.5174  30777845700  328209202377.8000  -1.516979
# 3   2923.4856  36645043600  393019665228.0000  -1.233428
# 4   2887.4265  35187866500  375627000794.2000  -3.400010
# 5   2789.2537  30614967700  323012822799.1000  -0.344644
# 6   2779.6407  28763249300  314897170509.9000  -1.799592
# 7   2728.7563  30230274700  330518008489.8000  -0.975782
# 8   2702.1296  25201950700  281583369664.4000   1.609419
# 9   2745.6182  24982025000  268423241973.7000  -3.112261
# 10  2660.1674  25702193000  278999306643.2000   2.340856
# 11  2722.4381  27314446600  293191204398.7000   2.172802
# 12  2781.5913  23408402200  248279785000.7000  -0.599671
# 13  2764.9109  24076406600  253630725892.3000   0.263748
# 14  2772.2033  23970660400  250687144232.8000  -0.901431
# 15  2747.2138  21859867400  224271061569.1000   0.112201
# 16  2750.2962  21725342700  225624646571.6000  -0.573564
# 17  2734.5215  21786460000  233111575711.2000   1.686452
# 18  2780.6379  20083740400  214062212038.2000  -0.598801

# %%
rs2 = bs.query_history_k_data_plus("sz.399001",
    "date,code,open,high,low,close,preclose,volume,amount,pctChg",
    start_date='2020-03-10', end_date='2020-04-03', frequency="d")
data = []
while (rs2.error_code == '0') & rs2.next():
    # 获取一条记录，将记录合并在一起
    data.append(rs2.get_row_data())
result = pd.DataFrame(data, columns=rs2.fields)

# %%
df = baostock_get_history_k_data("sz.399001",start_date='2020-03-10', end_date='2020-04-03', frequency="d")
df
# Out:
# login success!
#                 open      high       low     close  preclose        volume  \
# date
# 2020-03-10  11016.92  11406.30  10916.95  11403.47  11108.55  5.813552e+10
# 2020-03-11  11436.44  11444.78  11197.09  11200.05  11403.47  5.295802e+10
# 2020-03-12  11022.40  11070.41  10842.38  10941.01  11200.05  4.657079e+10
# 2020-03-13  10382.22  10956.51  10380.17  10831.12  10939.47  5.290045e+10
# 2020-03-16  10867.66  10867.66  10217.93  10253.28  10831.12  5.204826e+10
# 2020-03-17  10337.92  10449.33   9885.86  10202.75  10253.28  4.491643e+10
# 2020-03-18  10294.96  10479.78  10030.29  10035.36  10200.16  4.471348e+10
# 2020-03-19  10023.12  10101.80   9719.49  10019.86  10029.57  4.322377e+10
# 2020-03-20  10150.78  10174.51   9964.29  10150.13  10019.86  3.800470e+10
# 2020-03-23   9828.90   9929.96   9659.35   9691.53  10150.13  3.881146e+10
# 2020-03-24   9900.22   9945.92   9634.97   9921.68   9691.53  3.983593e+10
# 2020-03-25  10171.47  10255.58  10111.36  10241.08   9921.68  4.168394e+10
# 2020-03-26  10161.94  10281.57  10112.62  10155.36  10241.08  3.729923e+10
# 2020-03-27  10300.62  10310.53  10105.72  10109.91  10155.36  3.450099e+10
# 2020-03-30   9953.04   9985.38   9791.02   9904.95  10109.91  3.566314e+10
# 2020-03-31  10008.03  10047.98   9925.68   9962.30   9904.95  3.153483e+10
# 2020-04-01   9967.12  10127.10   9927.92   9951.84   9962.30  3.330795e+10
# 2020-04-02   9910.38  10179.20   9896.65  10179.20   9951.84  3.282008e+10
# 2020-04-03  10155.56  10212.91  10069.64  10110.11  10179.20  3.200313e+10
#
#             amount    turn  tradestatus  pctChg  isST
# date
# 2020-03-10  6565.0  626.61          1.0    2.65   0.0
# 2020-03-11  5941.0  570.65          1.0   -1.78   0.0
# 2020-03-12  5094.0  501.78          1.0   -2.31   0.0
# 2020-03-13  5737.0  569.45          1.0   -0.99   0.0
# 2020-03-16  5877.0  560.27          1.0   -5.33   0.0
# 2020-03-17  4951.0  483.52          1.0   -0.49   0.0
# 2020-03-18  5125.0  487.18          1.0   -1.62   0.0
# 2020-03-19  4919.0  464.94          1.0   -0.10   0.0
# 2020-03-20  4355.0  408.61          1.0    1.30   0.0
# 2020-03-23  4190.0  417.28          1.0   -4.52   0.0
# 2020-03-24  4335.0  428.29          1.0    2.37   0.0
# 2020-03-25  4582.0  448.01          1.0    3.22   0.0
# 2020-03-26  3942.0  401.02          1.0   -0.84   0.0
# 2020-03-27  3803.0  370.06          1.0   -0.45   0.0
# 2020-03-30  3824.0  382.47          1.0   -2.03   0.0
# 2020-03-31  3375.0  338.11          1.0    0.58   0.0
# 2020-04-01  3592.0  357.13          1.0   -0.11   0.0
# 2020-04-02  3646.0  351.69          1.0    2.28   0.0
# 2020-04-03  3583.0  342.89          1.0   -0.68   0.0

# %% [markdown]
# # mplfinance

# %%
import tushare as ts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplfinance as mpf

# %% [markdown]
# ## 数据格式要求
# index为data，且为日期格式（parse_dates=True或者to_datetime）

# %%
from IPython.display import Image
Image(filename='C:/Users/86188/Desktop/mplfinance.jpg',width=600,height=400)

# %%
daily = ts.get_k_data("601398", start="2020-03-01", end="2020-08-01")
daily["date"]=pd.to_datetime(daily["date"])
daily = daily.set_index("date")

# %% [markdown]
# ## 蜡烛图

# %%
mpf.plot(daily,type='candle')

# %% [markdown]
# ## 折线图

# %%
mpf.plot(daily,type='line')

# %% [markdown]
# ## 添加MA线

# %%
mpf.plot(daily,type='candle',mav=(5,10,20,30),volume=True)
