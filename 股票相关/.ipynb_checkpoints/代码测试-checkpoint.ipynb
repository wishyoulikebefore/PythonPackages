# %%
import datetime
import tushare as ts
import pandas as pd
import numpy as np

# %%
example_df = pd.read_csv("/Users/zty/Documents/stock_data/historical_data/603393.SH.csv")
example_df = example_df.iloc[::-1,:]

# %%
ma30 = ma(example_df, n=30, val_name="close")

# %%
example_df.head()
# Out:
#        ts_code  trade_date   open   high    low  close  pre_close  change  \
# 410  603393.SH    20210104  23.59  23.59  23.03  23.22      23.62   -0.40
# 409  603393.SH    20210105  23.24  23.24  22.76  22.85      23.22   -0.37
# 408  603393.SH    20210106  22.89  23.50  22.89  23.14      22.85    0.29
# 407  603393.SH    20210107  23.08  23.08  22.38  22.48      23.14   -0.66
# 406  603393.SH    20210108  22.38  22.38  21.80  22.10      22.48   -0.38
#
#      pct_chg       vol      amount
# 410  -1.6935  53852.49  125012.493
# 409  -1.5935  54352.46  124361.145
# 408   1.2691  43025.29   99708.342
# 407  -2.8522  53121.11  120027.245
# 406  -1.6904  35580.16   78587.186

# %%
example_df["close"].tolist()[-1]
# Out:
# 24.76

# %%
ma30[-1]
# Out:
# 24.81

# %%
import datetime
import tushare as ts

# %%
ts.set_token('409115656486e3f61481103ec280339511aee50ee9026f9b008985ea')
pro = ts.pro_api()
df = pro.daily(trade_date="20220907")

# %%
df.head()
# Out:
#      ts_code trade_date   open   high    low  close  pre_close  change  \
# 0  000001.SZ   20220907  12.42  12.42  12.28  12.33      12.50   -0.17
# 1  000002.SZ   20220907  17.66  17.82  17.40  17.52      17.85   -0.33
# 2  000004.SZ   20220907   9.40   9.40   9.21   9.26       9.40   -0.14
# 3  000005.SZ   20220907   1.86   1.88   1.84   1.88       1.87    0.01
# 4  000006.SZ   20220907   4.45   4.49   4.40   4.48       4.47    0.01
#
#    pct_chg        vol       amount
# 0  -1.3600  979812.81  1208329.759
# 1  -1.8487  883386.10  1550325.356
# 2  -1.4894   15953.00    14793.834
# 3   0.5348   53025.60     9896.215
# 4   0.2237  143350.16    63829.497

# %%
df[df["ts_code"]=="000001.SZ"]
# Out:
#      ts_code trade_date   open   high    low  close  pre_close  change  \
# 0  000001.SZ   20220907  12.42  12.42  12.28  12.33       12.5   -0.17
#
#    pct_chg        vol       amount
# 0    -1.36  979812.81  1208329.759

# %%
ma_dict = {"ma5":20,"ma10":30}

# %%
np.array(ma_dict.values())
# Out:
# array(dict_values([20, 30]), dtype=object)

# %%
ts.set_token('409115656486e3f61481103ec280339511aee50ee9026f9b008985ea')
pro = ts.pro_api()
df = pro.daily(trade_date="20220914")

# %%
empty_df = df[df["ts_code"]=="000510.SZ"]

# %%
empty_df.empty
# Out:
# True

# %%
raw_df.index
# Out:
# RangeIndex(start=0, stop=415, step=1)

# %%
raw_df.index[0]
# Out:
# 0

# %%
import mplfinance as mpl

# %%
raw_df.head()
# Out:
#      ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0  000001.SZ    20210104  19.10  19.10  18.44  18.60      19.34   -0.74
# 1  000001.SZ    20210105  18.40  18.48  17.80  18.17      18.60   -0.43
# 2  000001.SZ    20210106  18.08  19.56  18.00  19.56      18.17    1.39
# 3  000001.SZ    20210107  19.52  19.98  19.23  19.90      19.56    0.34
# 4  000001.SZ    20210108  19.90  20.10  19.31  19.85      19.90   -0.05
#
#    pct_chg         vol       amount
# 0  -3.8263  1554216.43  2891682.312
# 1  -2.3118  1821352.10  3284606.913
# 2   7.6500  1934945.12  3648521.909
# 3   1.7382  1584185.30  3111274.625
# 4  -0.2513  1195473.22  2348316.363

# %%
raw_df["trade_date"] = pd.to_datetime(raw_df["trade_date"],format='%Y%m%d')

# %%
import numpy as np
import mplfinance as mpl
import pandas as pd

def ma(data, n=10, val_name="close"):
    values = []
    MA = []

    for index, row in data.iterrows():
        values.append(row[val_name])
        MA.append(np.average(values))
        ### 确保array长度最大为n
        if len(values) == n:
            del values[0]

    return np.around(MA,decimals=2)

def ema(data, n=12, val_name="close"):
    past_ema = None
    EMA = []

    for index, row in data.iterrows():
        if index == data.index[0]:
            past_ema = row[val_name]
            EMA.append(row[val_name])
        else:
            today_ema = (2 * row[val_name] + (n - 1) * past_ema) / (n + 1)
            past_ema = today_ema
            EMA.append(today_ema)

    return EMA

def macd(data, ema_return=False, quick_n=12, slow_n=26, dem_n=9, val_name="close"):
    ema_quick = np.asarray(ema(data, quick_n, val_name))
    ema_slow = np.asarray(ema(data, slow_n, val_name))
    DIFF = ema_quick - ema_slow
    data["diff"] = DIFF
    DEM = ema(data, dem_n, val_name="diff")
    OSC = DIFF - DEM
    if not ema:
        return np.around(DIFF,decimals=3),np.around(DEM,decimals=3), np.around(2*OSC,decimals=3)
    else:
        return np.around(ema_quick,decimals=3),np.around(ema_slow,decimals=3), np.around(DIFF,decimals=3),np.around(DEM,decimals=3), np.around(2*OSC,decimals=3)
    
def draw_Kline(df,stock_code):
    df.rename(columns={"vol":"volume"},inplace=True)
    df["trade_date"] = pd.to_datetime(df["trade_date"],format='%Y%m%d')
    df.set_index("trade_date", inplace=True)

    # 符合中国习惯的配色风格——红涨绿跌自然是必须实现的第一步
    my_color = mpl.make_marketcolors(up='r',
                                     down='g',
                                     edge='inherit',
                                     wick='inherit',
                                     volume='inherit')
    # 设置图表的背景色
    my_style = mpl.make_mpf_style(marketcolors=my_color,
                                  figcolor='(0.82, 0.83, 0.85)',
                                  gridcolor='(0.82, 0.83, 0.85)')

    df["diff"],df["dem"],df["macd_volume"] = macd(df)
    df["ma120"] = ma(df,n=120)
    df["ma250"] = ma(df,n=250)
    plot_df = df.iloc[-120:,]
    bar_r = np.where(plot_df['macd_volume'] > 0, plot_df['macd_volume'], 0)
    add_plot = [mpl.make_addplot(plot_df[["diff","dem"]],panel=2),
                mpl.make_addplot(plot_df["ma120"], color="grey",panel=0),
                mpl.make_addplot(plot_df["ma250"], color="blue",panel=0),
                mpl.make_addplot(bar_r, type='bar',color="red",panel=2)]
    mpl.plot(plot_df, type = 'candle',style=my_style,figsize=(12, 8),title=stock_code,addplot=add_plot,
                 mav = (5,10,20, 30, 60),volume = True)

# %%
def get_history_pro(stock_code, start_date):
#    ts.set_token('409115656486e3f61481103ec280339511aee50ee9026f9b008985ea')
    ts.set_token('9d3281af4abe819ab1a6a7fbdf4c8c0ef5622ffc24edb3f7df572e44')
    pro = ts.pro_api()
    df = pro.daily(ts_code=stock_code, start_date=start_date)
    df = df.iloc[::-1, :]  ### tushare的数据是按时间倒叙排列的，后续分析需要改成顺序
    return df

# %%
df = get_history_pro("601888.SH","2018-01-01")

# %%
df.head()
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 1152  601888.SH   20180102  43.75  44.00  42.82  43.05      43.39   -0.34
# 1151  601888.SH   20180103  43.53  45.73  42.62  45.68      43.05    2.63
# 1150  601888.SH   20180104  45.35  46.10  44.85  45.47      45.68   -0.21
# 1149  601888.SH   20180105  45.49  45.60  44.56  45.17      45.47   -0.30
# 1148  601888.SH   20180108  45.48  46.50  45.00  46.47      45.17    1.30
#
#       pct_chg        vol      amount
# 1152    -0.78   67986.08  293906.582
# 1151     6.11  182387.87  803835.010
# 1150    -0.46  145042.21  659567.833
# 1149    -0.66   71144.93  319351.080
# 1148     2.88  128763.91  589506.971

# %%
### 东方财富、同花顺的MACD是从股票上市第一天算的，因此算的值会不一样
def find_my_kickpoint_MACD(data,stock_code):
    """
    寻找金叉-死叉-第二次金叉，满足以下特征：
    1）第二次金叉位置比第一次高，但DIFF为负
    2）两次金叉间相隔20个交易日（调整需要时间，定4周）
    3）过程中股价没有20%以上的上涨（确保是底部盘整）
    4）第二次金叉出现后，连续3天macd差值增大（确认上升趋势）
    5）如果第二次金叉不满足，重新往后寻找死叉-金叉

    由于是检测当日收盘是否符合，所以逻辑要反过来：
    1）当天是否是第二次金叉后macd差值连续增大的第三天
    2）定位第二次金叉
    3）往前推死叉-金叉
    4）（严格）出现DIFF为正的金叉/死叉，直接终止（希望下跌中调整）
    5）第一次金叉需要满足：DIFF低于第二次金叉DIFF，未上涨超过20%，两次相隔查过20个交易日
    """
    ### 倒数第四日是金叉，且后3日macd差值增大
    data["diff"], data["dem"], data["macd_volume"] = macd(data)
    macd_volume = data["macd_volume"].tolist()
    diff = data["diff"].tolist()
    close = data["close"].tolist()
    count = len(diff)
    highest_price = close[count - 5]
    ### 确认存在死叉，位置无所谓
    label = 0

    ### 判断第一次的金叉是否满足特征:DIFF低于第二次金叉DIFF，未上涨超过20%，两次相隔查过20个交易日
    def judge_positive_cross(loc, second_loc, highest_price):
        if macd_volume[loc] >= 0 and macd_volume[loc - 1] < 0:
            if diff[loc - 1] > 0:
                return "stop"
            elif diff[loc - 1] < diff[second_loc] and second_loc - loc >= 20 and highest_price / close[loc] < 1.2:
                return "go"
            else:
                pass

    if macd_volume[count - 1] > macd_volume[count - 2] > macd_volume[count - 3] > macd_volume[count - 4] >= 0 and macd_volume[count - 5] < 0 and diff[count - 5] < 0:
        pass
    else:
        return

    for loc in range(count - 5, 1, -1):
        ### 确认存在死叉（倒推角度，diff_value由负转正）
        if label == 1:
            positive_result = judge_positive_cross(loc, count - 4, highest_price)
            if positive_result == "go":
                print("今日%s符合MACD底背离" % (stock_code))
                break
            elif positive_result == "stop":
                break
            else:
                pass
        elif macd_volume[loc] < 0 and macd_volume[loc - 1] >= 0:
            if diff[loc - 1] > 0:
                break
            else:
                label = 1
        else:
            pass

        highest_price = max(highest_price, close[loc])

# %%
def get_history_pro2(stock_code, start_date,end_date):
#    ts.set_token('409115656486e3f61481103ec280339511aee50ee9026f9b008985ea')
    ts.set_token('9d3281af4abe819ab1a6a7fbdf4c8c0ef5622ffc24edb3f7df572e44')
    pro = ts.pro_api()
    df = pro.daily(ts_code=stock_code, start_date=start_date,end_date=end_date)
    df = df.iloc[::-1, :]  ### tushare的数据是按时间倒叙排列的，后续分析需要改成顺序
    return df

# %% [markdown]
# 优化思路：
#
# 1、ma和macd存储在csv中，每天只算今天的，避免每天重新计算
#
# 2、ma判断当日与上方最近ma的距离，以及之前20个交易日有无逼近此ma
#
# 3、增加boll线判断

# %% [markdown]
# ### 只需要存储2021年开始的数据，测试下来不影响macd的结果

# %%
data1 = get_history_pro("601888.SH","2018-01-01")
data3 = get_history_pro("601888.SH","2021-01-01")

# %%
draw_Kline(data1,"2018")

# %%
draw_Kline(data3,"2021")

# %% [markdown]
# ### ma和macd存储在csv中，每天只算今天的，避免每天重新计算

# %%
def add_ma_macd_history(data):
    data["ma5"] = ma(data,n=5)
    data["ma10"] = ma(data,n=10)
    data["ma20"] = ma(data,n=20)
    data["ma30"] = ma(data,n=30)
    data["ma60"] = ma(data,n=60)
    data["ma120"] = ma(data,n=120)
    data["ma250"] = ma(data,n=250)
    data["ema_quick"],data["ema_slow"],data["diff"], data["dem"], data["macd_volume"] = macd(data,ema_return=True)
    data.drop("ts_code",axis=1,inplace=True)
    return data

# %%
data3 = get_history_pro("601888.SH","2021-01-01")

# %%
data3_add = add_ma_macd_history(data3)

# %%
data3.head()
# Out:
#     trade_date    open    high     low   close  pre_close  change  pct_chg  \
# 423   20210104  282.00  300.62  281.75  292.25     282.45    9.80   3.4696
# 422   20210105  290.00  299.69  289.00  293.02     292.25    0.77   0.2635
# 421   20210106  290.00  293.83  284.02  288.00     293.02   -5.02  -1.7132
# 420   20210107  293.35  311.00  290.00  311.00     288.00   23.00   7.9861
# 419   20210108  311.00  311.40  287.00  291.00     311.00  -20.00  -6.4309
#
#            vol       amount     ma5    ma10    ma20    ma30    ma60   ma120  \
# 423  140347.48  4127327.801  292.25  292.25  292.25  292.25  292.25  292.25
# 422  118713.65  3480973.443  292.64  292.64  292.64  292.64  292.64  292.64
# 421  126380.99  3640459.354  291.09  291.09  291.09  291.09  291.09  291.09
# 420  151153.16  4534780.266  296.07  296.07  296.07  296.07  296.07  296.07
# 419  196177.12  5823692.598  295.05  295.05  295.05  295.05  295.05  295.05
#
#       ma250   diff    dem  macd_volume
# 423  292.25  0.000  0.000        0.000
# 422  292.64  0.061  0.012        0.098
# 421  291.09 -0.292 -0.048       -0.486
# 420  296.07  1.270  0.215        2.109
# 419  295.05  0.883  0.349        1.069

# %%
ts.set_token('409115656486e3f61481103ec280339511aee50ee9026f9b008985ea')
pro = ts.pro_api()
df = pro.daily(trade_date="20220929")

# %%
select_df = df[df["ts_code"]=="601888.SH"]

# %%
select_df
# Out:
#         ts_code trade_date    open   high     low   close  pre_close  change  \
# 3662  601888.SH   20220929  203.33  203.5  196.06  197.25     202.48   -5.23
#
#       pct_chg       vol       amount
# 3662   -2.583  95696.93  1900485.778

# %%
def ma_v2(data1, data2, n=10, val_name="close"):
    today_ma = (data1[val_name]+data2.iloc[-n+1:,][val_name].sum())/n
    return np.around(today_ma,decimals=2)

def ema_v2(data1, data2, n=12, val_name="close", val_name2="close"):
    today_ema = (2 * data1[val_name] + (n - 1) * data2.iloc[-1,][val_name2]) / (n + 1)
    return today_ema

def macd_v2(data1, data2, ema_return=False, quick_n=12, slow_n=26, dem_n=9, val_name="close"):
    ema_quick = np.asarray(ema_v2(data1, data2, quick_n, val_name, "ema_quick"))
    ema_slow = np.asarray(ema_v2(data1, data2, slow_n, val_name, "ema_slow"))
    DIFF = ema_quick - ema_slow
    data1["diff"] = DIFF
    DEM = ema_v2(data1, data2, dem_n, "diff", "dem")
    OSC = DIFF - DEM
    if not ema:
        return np.around(DIFF,decimals=3),np.around(DEM,decimals=3), np.around(2*OSC,decimals=3)
    else:
        return np.around(ema_quick,decimals=3),np.around(ema_slow,decimals=3), np.around(DIFF,decimals=3),np.around(DEM,decimals=3), np.around(2*OSC,decimals=3)

# %%
def add_ma_macd_today(data_today,data_history):
    data_today.drop("ts_code",axis=1,inplace=True)
    data_today["ma5"] = ma_v2(data_today,data_history,n=5)
    data_today["ma10"] = ma_v2(data_today,data_history,n=10)
    data_today["ma20"] = ma_v2(data_today,data_history,n=20)
    data_today["ma30"] = ma_v2(data_today,data_history,n=30)
    data_today["ma60"] = ma_v2(data_today,data_history,n=60)
    data_today["ma120"] = ma_v2(data_today,data_history,n=120)
    data_today["ma250"] = ma_v2(data_today,data_history,n=250)
    data_today["ema_quick"],data_today["ema_slow"],data_today["diff"], data_today["dem"], data_today["macd_volume"] = macd_v2(data_today,data_history)
    return data_today

# %% [markdown]
# ### ma判断当日与上方最近ma的距离，以及之前20个交易日有无逼近此ma
